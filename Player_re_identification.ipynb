# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.18)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.3.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %% [markdown]
# Bot-Sort

# %%
# !pip install ultralytics opencv-python numpy scipy scikit-learn
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.18)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.3.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
import cv2
import numpy as np
from collections import deque
from ultralytics import YOLO
from scipy.optimize import linear_sum_assignment
from sklearn.metrics.pairwise import cosine_similarity

# %%
TRAJ_LEN = 30
EMA_ALPHA = 0.85
APPEARANCE_WEIGHT = 0.7
MOTION_WEIGHT = 0.3
MATCH_THRESHOLD = 0.45
PLAYER_CLASS_ID = 2

# %%
def extract_embedding(frame, bbox):
    x1, y1, x2, y2 = map(int, bbox)
    crop = frame[y1:y2, x1:x2]

    if crop.size == 0:
        return np.zeros(512)

    hist = cv2.calcHist(
        [crop], [0, 1, 2], None,
        [8, 8, 8],
        [0, 256, 0, 256, 0, 256]
    )

    cv2.normalize(hist, hist)
    emb = hist.flatten()
    emb = emb / (np.linalg.norm(emb) + 1e-6)

    return emb

# %%
def extract_embedding(frame, bbox):
    x1, y1, x2, y2 = map(int, bbox)
    crop = frame[y1:y2, x1:x2]

    if crop.size == 0:
        return np.zeros(512)

    hist = cv2.calcHist(
        [crop], [0, 1, 2], None,
        [8, 8, 8],
        [0, 256, 0, 256, 0, 256]
    )

    cv2.normalize(hist, hist)
    emb = hist.flatten()
    emb = emb / (np.linalg.norm(emb) + 1e-6)

    return emb

# %%
def get_center(bbox):
    x1, y1, x2, y2 = bbox
    return ((x1 + x2) // 2, (y1 + y2) // 2)

# %%
def extract_embedding(frame, bbox):
    x1, y1, x2, y2 = map(int, bbox)
    crop = frame[y1:y2, x1:x2]

    if crop.size == 0:
        return np.zeros(512)

    hist = cv2.calcHist(
        [crop], [0, 1, 2], None,
        [8, 8, 8],
        [0, 256, 0, 256, 0, 256]
    )

    cv2.normalize(hist, hist)
    emb = hist.flatten()
    emb = emb / (np.linalg.norm(emb) + 1e-6)

    return emb


def get_center(bbox):
    x1, y1, x2, y2 = bbox
    return ((x1 + x2) // 2, (y1 + y2) // 2)

# %%
class CameraProcessor:

    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.identity_db = {}

    def process_video(self, video_path):

        results = self.model.track(
            source=video_path,
            tracker="botsort.yaml",
            persist=True,
            classes=[PLAYER_CLASS_ID],
            stream=True
        )

        for result in results:

            frame = result.orig_img
            boxes = result.boxes

            if boxes.id is None:
                continue

            for box, track_id in zip(boxes.xyxy, boxes.id):

                track_id = int(track_id.item())
                x1, y1, x2, y2 = map(int, box.tolist())

                bbox = (x1, y1, x2, y2)
                center = get_center(bbox)
                embedding = extract_embedding(frame, bbox)

                self.update_identity(track_id, embedding, center)

    def update_identity(self, track_id, embedding, center):

        if track_id not in self.identity_db:
            self.identity_db[track_id] = {
                "embedding": embedding,
                "trajectory": deque(maxlen=TRAJ_LEN),
                "velocity": np.zeros(2)
            }
        else:
            # EMA smoothing
            self.identity_db[track_id]["embedding"] = (
                EMA_ALPHA * self.identity_db[track_id]["embedding"]
                + (1 - EMA_ALPHA) * embedding
            )

        traj = self.identity_db[track_id]["trajectory"]

        if len(traj) > 0:
            prev = np.array(traj[-1])
            velocity = np.array(center) - prev
            self.identity_db[track_id]["velocity"] = velocity

        traj.append(center)

    def get_database(self):
        return self.identity_db

# %% [markdown]
# Cross Camera Matching

# %%
def compute_motion_distance(v1, v2):

    if np.linalg.norm(v1) == 0 or np.linalg.norm(v2) == 0:
        return 1.0

    direction_sim = cosine_similarity([v1], [v2])[0][0]
    speed_diff = abs(np.linalg.norm(v1) - np.linalg.norm(v2))

    return (1 - direction_sim) + 0.01 * speed_diff


def cross_camera_match(db_x, db_y):

    ids_x = list(db_x.keys())
    ids_y = list(db_y.keys())

    if not ids_x or not ids_y:
        return {}

    cost_matrix = np.zeros((len(ids_x), len(ids_y)))

    for i, id_x in enumerate(ids_x):
        for j, id_y in enumerate(ids_y):

            emb_x = db_x[id_x]["embedding"]
            emb_y = db_y[id_y]["embedding"]

            appearance_dist = 1 - cosine_similarity(
                [emb_x], [emb_y]
            )[0][0]

            motion_dist = compute_motion_distance(
                db_x[id_x]["velocity"],
                db_y[id_y]["velocity"]
            )

            cost = (
                APPEARANCE_WEIGHT * appearance_dist +
                MOTION_WEIGHT * motion_dist
            )

            cost_matrix[i, j] = cost

    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    matches = {}

    for r, c in zip(row_ind, col_ind):
        if cost_matrix[r, c] < MATCH_THRESHOLD:
            matches[ids_y[c]] = ids_x[r]

    return matches

# %% [markdown]
# Main Loop

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %%
PLAYER_CLASS_ID = 2  # Replace with your player class ID in YOLO
MODEL_PATH = "/content/drive/MyDrive/best.pt"

# %%
class CameraProcessor:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.db = {}  # {track_id: {"embedding":..., "frames":[], "bbox_history":[], "centers":[]}}

    def get_database(self):
        return self.db

    def get_histogram(self, frame, bbox):
        x1, y1, x2, y2 = map(int, bbox)
        crop = frame[y1:y2, x1:x2]
        if crop.size == 0:
            return np.zeros((512,))
        hist = cv2.calcHist([crop], [0,1,2], None, [8,8,8], [0,256,0,256,0,256])
        cv2.normalize(hist, hist)
        return hist.flatten()

    def process_video(self, video_path):
        cap = cv2.VideoCapture(video_path)
        frame_idx = 0

        results_stream = self.model.track(
            source=video_path,
            tracker="botsort.yaml",
            persist=True,
            classes=[PLAYER_CLASS_ID],
            stream=True
        )

        for result in results_stream:
            frame = result.orig_img
            boxes = result.boxes
            frame_idx += 1

            if boxes.id is not None:
                for box, track_id in zip(boxes.xyxy, boxes.id):
                    track_id = int(track_id.item())
                    x1, y1, x2, y2 = map(int, box.tolist())
                    center = ((x1+x2)//2, (y1+y2)//2)
                    hist = self.get_histogram(frame, (x1, y1, x2, y2))
                    hist = hist / np.linalg.norm(hist) if np.linalg.norm(hist) > 0 else hist

                    if track_id not in self.db:
                        self.db[track_id] = {
                            "embedding": hist,
                            "frames": [],
                            "bbox_history": [],
                            "centers": []
                        }

                    # Append per-frame data
                    self.db[track_id]["frames"].append(frame_idx)
                    self.db[track_id]["bbox_history"].append((x1, y1, x2, y2))
                    self.db[track_id]["centers"].append(center)

                    # Moving average for embedding
                    self.db[track_id]["embedding"] = 0.9*self.db[track_id]["embedding"] + 0.1*hist

        cap.release()

# %%
def cross_camera_match(db_x, db_y, threshold=0.7):
    matches = {}
    for y_id, y_data in db_y.items():
        best_score = float('inf')
        best_x_id = None
        for x_id, x_data in db_x.items():
            emb_x = x_data["embedding"] / np.linalg.norm(x_data["embedding"])
            emb_y = y_data["embedding"] / np.linalg.norm(y_data["embedding"])
            score = 1 - np.dot(emb_x, emb_y)  # 1 - cosine similarity

            if score < best_score:
                best_score = score
                best_x_id = x_id

        if best_score < (1 - threshold):
            matches[y_id] = best_x_id

    return matches

# %%
cam_x = CameraProcessor(MODEL_PATH)
cam_y = CameraProcessor(MODEL_PATH)

print("Processing Camera X...")
cam_x.process_video("/content/drive/MyDrive/broadcast.mp4")

print("Processing Camera Y...")
cam_y.process_video("/content/drive/MyDrive/tacticam.mp4")


print("\nMatching identities...")
matches = cross_camera_match(
    cam_x.get_database(),
    cam_y.get_database()
)

print("\nCross-Camera ID Mapping:")
for y_id, x_id in matches.items():
    print(f"Camera Y ID {y_id} → Camera X ID {x_id}")


global_map_x = {}
global_map_y = {}

next_global_id = 1
for y_id, x_id in matches.items():
    global_map_x[x_id] = next_global_id
    global_map_y[y_id] = next_global_id
    next_global_id += 1


def write_output_video(video_path, output_path, global_map):
    model = YOLO(MODEL_PATH)
    cap = cv2.VideoCapture(video_path)

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    out = cv2.VideoWriter(
        output_path,
        cv2.VideoWriter_fourcc(*"mp4v"),
        fps,
        (width, height)
    )

    results_stream = model.track(
        source=video_path,
        tracker="botsort.yaml",
        persist=True,
        classes=[PLAYER_CLASS_ID],
        stream=True
    )

    for result in results_stream:
        frame = result.orig_img
        boxes = result.boxes

        if boxes.id is not None:
            for box, track_id in zip(boxes.xyxy, boxes.id):
                track_id = int(track_id.item())
                x1, y1, x2, y2 = map(int, box.tolist())

                if track_id in global_map:
                    gid = global_map[track_id]
                    label = f"GLOBAL ID: {gid}"
                else:
                    label = "GLOBAL ID: ?"

                cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
                cv2.putText(frame, label,
                            (x1, y1-10),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.7,
                            (0,255,0),
                            2)

        out.write(frame)

    cap.release()
    out.release()

print("\nWriting output videos...")
write_output_video("/content/drive/MyDrive/broadcast.mp4",
                   "/content/broadcast_with_global_ids.mp4",
                   global_map_x)

write_output_video("/content/drive/MyDrive/tacticam.mp4",
                   "/content/tacticam_with_global_ids.mp4",
                   global_map_y)

print("\nDone. Videos saved.")
# Out:
# Processing Camera X...
#
# video 1/1 (frame 1/132) /content/drive/MyDrive/broadcast.mp4: 384x640 3 players, 67.1ms
# video 1/1 (frame 2/132) /content/drive/MyDrive/broadcast.mp4: 384x640 1 player, 43.7ms
# video 1/1 (frame 3/132) /content/drive/MyDrive/broadcast.mp4: 384x640 5 players, 50.2ms
# video 1/1 (frame 4/132) /content/drive/MyDrive/broadcast.mp4: 384x640 2 players, 42.7ms
# video 1/1 (frame 5/132) /content/drive/MyDrive/broadcast.mp4: 384x640 4 players, 40.4ms
# video 1/1 (frame 6/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.5ms
# video 1/1 (frame 7/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 8/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 44.9ms
# video 1/1 (frame 9/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 42.2ms
# video 1/1 (frame 10/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.4ms
# video 1/1 (frame 11/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.4ms
# video 1/1 (frame 12/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.4ms
# video 1/1 (frame 13/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 44.4ms
# video 1/1 (frame 14/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 42.3ms
# video 1/1 (frame 15/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.4ms
# video 1/1 (frame 16/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 41.0ms
# video 1/1 (frame 17/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 58.1ms
# video 1/1 (frame 18/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 47.2ms
# video 1/1 (frame 19/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 47.5ms
# video 1/1 (frame 20/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 47.0ms
# video 1/1 (frame 21/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 69.9ms
# video 1/1 (frame 22/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 51.9ms
# video 1/1 (frame 23/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 53.4ms
# video 1/1 (frame 24/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 52.0ms
# video 1/1 (frame 25/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 51.2ms
# video 1/1 (frame 26/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 46.2ms
# video 1/1 (frame 27/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 46.2ms
# video 1/1 (frame 28/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 46.1ms
# video 1/1 (frame 29/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 45.6ms
# video 1/1 (frame 30/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 65.2ms
# video 1/1 (frame 31/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.7ms
# video 1/1 (frame 32/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.5ms
# video 1/1 (frame 33/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.7ms
# video 1/1 (frame 34/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 46.6ms
# video 1/1 (frame 35/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 47.1ms
# video 1/1 (frame 36/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 47.9ms
# video 1/1 (frame 37/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 41.4ms
# video 1/1 (frame 38/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.4ms
# video 1/1 (frame 39/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 72.5ms
# video 1/1 (frame 40/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.0ms
# video 1/1 (frame 41/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 53.5ms
# video 1/1 (frame 42/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.4ms
# video 1/1 (frame 43/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.4ms
# video 1/1 (frame 44/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 43.9ms
# video 1/1 (frame 45/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.4ms
# video 1/1 (frame 46/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 42.8ms
# video 1/1 (frame 47/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 43.2ms
# video 1/1 (frame 48/132) /content/drive/MyDrive/broadcast.mp4: 384x640 8 players, 40.9ms
# video 1/1 (frame 49/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 56.9ms
# video 1/1 (frame 50/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 76.9ms
# video 1/1 (frame 51/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 53.4ms
# video 1/1 (frame 52/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 69.9ms
# video 1/1 (frame 53/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 52.7ms
# video 1/1 (frame 54/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 95.9ms
# video 1/1 (frame 55/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 89.2ms
# video 1/1 (frame 56/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 70.8ms
# video 1/1 (frame 57/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 73.5ms
# video 1/1 (frame 58/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 65.7ms
# video 1/1 (frame 59/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 64.8ms
# video 1/1 (frame 60/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 64.4ms
# video 1/1 (frame 61/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 48.1ms
# video 1/1 (frame 62/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 48.2ms
# video 1/1 (frame 63/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 48.0ms
# video 1/1 (frame 64/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 48.1ms
# video 1/1 (frame 65/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 52.0ms
# video 1/1 (frame 66/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 41.8ms
# video 1/1 (frame 67/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.8ms
# video 1/1 (frame 68/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.7ms
# video 1/1 (frame 69/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 41.0ms
# video 1/1 (frame 70/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.8ms
# video 1/1 (frame 71/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.9ms
# video 1/1 (frame 72/132) /content/drive/MyDrive/broadcast.mp4: 384x640 13 players, 39.9ms
# video 1/1 (frame 73/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.6ms
# video 1/1 (frame 74/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 42.5ms
# video 1/1 (frame 75/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.9ms
# video 1/1 (frame 76/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.7ms
# video 1/1 (frame 77/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.4ms
# video 1/1 (frame 78/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 79/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 34.0ms
# video 1/1 (frame 80/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 33.8ms
# video 1/1 (frame 81/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 34.1ms
# video 1/1 (frame 82/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 33.9ms
# video 1/1 (frame 83/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 33.8ms
# video 1/1 (frame 84/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 32.7ms
# video 1/1 (frame 85/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 33.2ms
# video 1/1 (frame 86/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.7ms
# video 1/1 (frame 87/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 31.9ms
# video 1/1 (frame 88/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.2ms
# video 1/1 (frame 89/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.8ms
# video 1/1 (frame 90/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 32.1ms
# video 1/1 (frame 91/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.8ms
# video 1/1 (frame 92/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 32.8ms
# video 1/1 (frame 93/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 33.3ms
# video 1/1 (frame 94/132) /content/drive/MyDrive/broadcast.mp4: 384x640 13 players, 32.0ms
# video 1/1 (frame 95/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 31.9ms
# video 1/1 (frame 96/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.8ms
# video 1/1 (frame 97/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 33.1ms
# video 1/1 (frame 98/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.7ms
# video 1/1 (frame 99/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.5ms
# video 1/1 (frame 100/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 32.1ms
# video 1/1 (frame 101/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.2ms
# video 1/1 (frame 102/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 32.6ms
# video 1/1 (frame 103/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.0ms
# video 1/1 (frame 104/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.3ms
# video 1/1 (frame 105/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 32.0ms
# video 1/1 (frame 106/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 31.8ms
# video 1/1 (frame 107/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 31.9ms
# video 1/1 (frame 108/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 31.6ms
# video 1/1 (frame 109/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 32.1ms
# video 1/1 (frame 110/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 32.7ms
# video 1/1 (frame 111/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 32.9ms
# video 1/1 (frame 112/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 32.8ms
# video 1/1 (frame 113/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 33.1ms
# video 1/1 (frame 114/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 32.8ms
# video 1/1 (frame 115/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 32.7ms
# video 1/1 (frame 116/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 32.8ms
# video 1/1 (frame 117/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 33.6ms
# video 1/1 (frame 118/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 34.2ms
# video 1/1 (frame 119/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 33.2ms
# video 1/1 (frame 120/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 33.7ms
# video 1/1 (frame 121/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 34.9ms
# video 1/1 (frame 122/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 34.6ms
# video 1/1 (frame 123/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 35.0ms
# video 1/1 (frame 124/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 34.6ms
# video 1/1 (frame 125/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 36.9ms
# video 1/1 (frame 126/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 34.4ms
# video 1/1 (frame 127/132) /content/drive/MyDrive/broadcast.mp4: 384x640 (no detections), 34.1ms
# video 1/1 (frame 128/132) /content/drive/MyDrive/broadcast.mp4: 384x640 2 players, 33.9ms
# video 1/1 (frame 129/132) /content/drive/MyDrive/broadcast.mp4: 384x640 1 player, 34.0ms
# video 1/1 (frame 130/132) /content/drive/MyDrive/broadcast.mp4: 384x640 (no detections), 34.1ms
# video 1/1 (frame 131/132) /content/drive/MyDrive/broadcast.mp4: 384x640 (no detections), 33.8ms
# video 1/1 (frame 132/132) /content/drive/MyDrive/broadcast.mp4: 384x640 1 player, 33.8ms
# Speed: 5.6ms preprocess, 42.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing Camera Y...
#
# video 1/1 (frame 1/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 44.6ms
# video 1/1 (frame 2/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 43.0ms
# video 1/1 (frame 3/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.1ms
# video 1/1 (frame 4/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 35.4ms
# video 1/1 (frame 5/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 35.3ms
# video 1/1 (frame 6/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.2ms
# video 1/1 (frame 7/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.4ms
# video 1/1 (frame 8/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.5ms
# video 1/1 (frame 9/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.4ms
# video 1/1 (frame 10/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.6ms
# video 1/1 (frame 11/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.7ms
# video 1/1 (frame 12/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.2ms
# video 1/1 (frame 13/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.1ms
# video 1/1 (frame 14/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.2ms
# video 1/1 (frame 15/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.3ms
# video 1/1 (frame 16/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.5ms
# video 1/1 (frame 17/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.6ms
# video 1/1 (frame 18/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.6ms
# video 1/1 (frame 19/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.7ms
# video 1/1 (frame 20/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.6ms
# video 1/1 (frame 21/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.9ms
# video 1/1 (frame 22/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 30.7ms
# video 1/1 (frame 23/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 31.2ms
# video 1/1 (frame 24/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.1ms
# video 1/1 (frame 25/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.7ms
# video 1/1 (frame 26/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.3ms
# video 1/1 (frame 27/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 31.0ms
# video 1/1 (frame 28/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 31.0ms
# video 1/1 (frame 29/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.9ms
# video 1/1 (frame 30/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.3ms
# video 1/1 (frame 31/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.5ms
# video 1/1 (frame 32/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.5ms
# video 1/1 (frame 33/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.0ms
# video 1/1 (frame 34/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.5ms
# video 1/1 (frame 35/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.0ms
# video 1/1 (frame 36/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.4ms
# video 1/1 (frame 37/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.3ms
# video 1/1 (frame 38/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.0ms
# video 1/1 (frame 39/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.9ms
# video 1/1 (frame 40/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.9ms
# video 1/1 (frame 41/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.9ms
# video 1/1 (frame 42/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.7ms
# video 1/1 (frame 43/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.3ms
# video 1/1 (frame 44/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.9ms
# video 1/1 (frame 45/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.7ms
# video 1/1 (frame 46/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 31.8ms
# video 1/1 (frame 47/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.9ms
# video 1/1 (frame 48/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 31.3ms
# video 1/1 (frame 49/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 30.6ms
# video 1/1 (frame 50/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 30.9ms
# video 1/1 (frame 51/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.9ms
# video 1/1 (frame 52/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.0ms
# video 1/1 (frame 53/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.1ms
# video 1/1 (frame 54/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.0ms
# video 1/1 (frame 55/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.4ms
# video 1/1 (frame 56/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 30.7ms
# video 1/1 (frame 57/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.8ms
# video 1/1 (frame 58/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.0ms
# video 1/1 (frame 59/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.1ms
# video 1/1 (frame 60/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 38.5ms
# video 1/1 (frame 61/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.6ms
# video 1/1 (frame 62/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.4ms
# video 1/1 (frame 63/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 64/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.7ms
# video 1/1 (frame 65/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 66/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.0ms
# video 1/1 (frame 67/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.1ms
# video 1/1 (frame 68/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 41.6ms
# video 1/1 (frame 69/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 70/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 71/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.2ms
# video 1/1 (frame 72/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 73/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.4ms
# video 1/1 (frame 74/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 75/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.5ms
# video 1/1 (frame 76/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.7ms
# video 1/1 (frame 77/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 78/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 79/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 80/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 39.4ms
# video 1/1 (frame 81/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 82/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.8ms
# video 1/1 (frame 83/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.4ms
# video 1/1 (frame 84/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.4ms
# video 1/1 (frame 85/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 41.3ms
# video 1/1 (frame 86/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 41.3ms
# video 1/1 (frame 87/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 88/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 36.9ms
# video 1/1 (frame 89/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 36.5ms
# video 1/1 (frame 90/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.9ms
# video 1/1 (frame 91/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.8ms
# video 1/1 (frame 92/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.2ms
# video 1/1 (frame 93/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.8ms
# video 1/1 (frame 94/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.8ms
# video 1/1 (frame 95/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.1ms
# video 1/1 (frame 96/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.5ms
# video 1/1 (frame 97/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.8ms
# video 1/1 (frame 98/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.6ms
# video 1/1 (frame 99/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.2ms
# video 1/1 (frame 100/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.7ms
# video 1/1 (frame 101/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.0ms
# video 1/1 (frame 102/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.1ms
# video 1/1 (frame 103/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 32.6ms
# video 1/1 (frame 104/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 32.8ms
# video 1/1 (frame 105/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 32.6ms
# video 1/1 (frame 106/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 32.5ms
# video 1/1 (frame 107/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 32.4ms
# video 1/1 (frame 108/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 32.8ms
# video 1/1 (frame 109/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 32.8ms
# video 1/1 (frame 110/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 33.4ms
# video 1/1 (frame 111/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 33.6ms
# video 1/1 (frame 112/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.7ms
# video 1/1 (frame 113/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 32.7ms
# video 1/1 (frame 114/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.1ms
# video 1/1 (frame 115/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.1ms
# video 1/1 (frame 116/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.2ms
# video 1/1 (frame 117/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 34.4ms
# video 1/1 (frame 118/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.3ms
# video 1/1 (frame 119/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.5ms
# video 1/1 (frame 120/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.5ms
# video 1/1 (frame 121/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.3ms
# video 1/1 (frame 122/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.1ms
# video 1/1 (frame 123/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.1ms
# video 1/1 (frame 124/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.2ms
# video 1/1 (frame 125/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.3ms
# video 1/1 (frame 126/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 32.3ms
# video 1/1 (frame 127/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.2ms
# video 1/1 (frame 128/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.5ms
# video 1/1 (frame 129/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.5ms
# video 1/1 (frame 130/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.8ms
# video 1/1 (frame 131/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.6ms
# video 1/1 (frame 132/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.1ms
# video 1/1 (frame 133/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.3ms
# video 1/1 (frame 134/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.1ms
# video 1/1 (frame 135/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.1ms
# video 1/1 (frame 136/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.1ms
# video 1/1 (frame 137/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.4ms
# video 1/1 (frame 138/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.9ms
# video 1/1 (frame 139/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.6ms
# video 1/1 (frame 140/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.7ms
# video 1/1 (frame 141/201) /content/drive/MyDrive/tacticam.mp4: 384x640 24 players, 33.4ms
# video 1/1 (frame 142/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 32.8ms
# video 1/1 (frame 143/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 32.9ms
# video 1/1 (frame 144/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.0ms
# video 1/1 (frame 145/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.4ms
# video 1/1 (frame 146/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.0ms
# video 1/1 (frame 147/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.8ms
# video 1/1 (frame 148/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.4ms
# video 1/1 (frame 149/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 33.2ms
# video 1/1 (frame 150/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.5ms
# video 1/1 (frame 151/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.0ms
# video 1/1 (frame 152/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 33.8ms
# video 1/1 (frame 153/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 33.8ms
# video 1/1 (frame 154/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 35.2ms
# video 1/1 (frame 155/201) /content/drive/MyDrive/tacticam.mp4: 384x640 24 players, 35.5ms
# video 1/1 (frame 156/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 35.2ms
# video 1/1 (frame 157/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 35.0ms
# video 1/1 (frame 158/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 35.0ms
# video 1/1 (frame 159/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.8ms
# video 1/1 (frame 160/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.6ms
# video 1/1 (frame 161/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.5ms
# video 1/1 (frame 162/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 32.5ms
# video 1/1 (frame 163/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 33.2ms
# video 1/1 (frame 164/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.8ms
# video 1/1 (frame 165/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.9ms
# video 1/1 (frame 166/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.6ms
# video 1/1 (frame 167/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 32.7ms
# video 1/1 (frame 168/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 32.7ms
# video 1/1 (frame 169/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 33.8ms
# video 1/1 (frame 170/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.8ms
# video 1/1 (frame 171/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 35.5ms
# video 1/1 (frame 172/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 36.1ms
# video 1/1 (frame 173/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 36.6ms
# video 1/1 (frame 174/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 36.7ms
# video 1/1 (frame 175/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 36.5ms
# video 1/1 (frame 176/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.9ms
# video 1/1 (frame 177/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.0ms
# video 1/1 (frame 178/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.0ms
# video 1/1 (frame 179/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 33.3ms
# video 1/1 (frame 180/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.1ms
# video 1/1 (frame 181/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.7ms
# video 1/1 (frame 182/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.4ms
# video 1/1 (frame 183/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 31.8ms
# video 1/1 (frame 184/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 32.7ms
# video 1/1 (frame 185/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.0ms
# video 1/1 (frame 186/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 35.2ms
# video 1/1 (frame 187/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 34.7ms
# video 1/1 (frame 188/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.1ms
# video 1/1 (frame 189/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 33.8ms
# video 1/1 (frame 190/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 34.0ms
# video 1/1 (frame 191/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 35.8ms
# video 1/1 (frame 192/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 35.3ms
# video 1/1 (frame 193/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 35.0ms
# video 1/1 (frame 194/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.8ms
# video 1/1 (frame 195/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.8ms
# video 1/1 (frame 196/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 34.0ms
# video 1/1 (frame 197/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 33.8ms
# video 1/1 (frame 198/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 33.4ms
# video 1/1 (frame 199/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 31.8ms
# video 1/1 (frame 200/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 32.1ms
# video 1/1 (frame 201/201) /content/drive/MyDrive/tacticam.mp4: 384x640 17 players, 31.7ms
# Speed: 3.8ms preprocess, 34.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Matching identities...
#
# Cross-Camera ID Mapping:
# Camera Y ID 1 → Camera X ID 22
# Camera Y ID 2 → Camera X ID 22
# Camera Y ID 3 → Camera X ID 74
# Camera Y ID 4 → Camera X ID 97
# Camera Y ID 5 → Camera X ID 12
# Camera Y ID 7 → Camera X ID 12
# Camera Y ID 8 → Camera X ID 94
# Camera Y ID 9 → Camera X ID 16
# Camera Y ID 10 → Camera X ID 19
# Camera Y ID 11 → Camera X ID 21
# Camera Y ID 12 → Camera X ID 74
# Camera Y ID 13 → Camera X ID 17
# Camera Y ID 14 → Camera X ID 74
# Camera Y ID 15 → Camera X ID 97
# Camera Y ID 16 → Camera X ID 97
# Camera Y ID 17 → Camera X ID 22
# Camera Y ID 18 → Camera X ID 74
# Camera Y ID 19 → Camera X ID 17
# Camera Y ID 20 → Camera X ID 22
# Camera Y ID 21 → Camera X ID 74
# Camera Y ID 22 → Camera X ID 13
# Camera Y ID 32 → Camera X ID 83
# Camera Y ID 33 → Camera X ID 85
# Camera Y ID 41 → Camera X ID 17
# Camera Y ID 46 → Camera X ID 74
# Camera Y ID 51 → Camera X ID 85
# Camera Y ID 64 → Camera X ID 85
#
# Writing output videos...
#
# video 1/1 (frame 1/132) /content/drive/MyDrive/broadcast.mp4: 384x640 3 players, 54.9ms
# video 1/1 (frame 2/132) /content/drive/MyDrive/broadcast.mp4: 384x640 1 player, 46.5ms
# video 1/1 (frame 3/132) /content/drive/MyDrive/broadcast.mp4: 384x640 5 players, 45.1ms
# video 1/1 (frame 4/132) /content/drive/MyDrive/broadcast.mp4: 384x640 2 players, 45.0ms
# video 1/1 (frame 5/132) /content/drive/MyDrive/broadcast.mp4: 384x640 4 players, 45.8ms
# video 1/1 (frame 6/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 45.1ms
# video 1/1 (frame 7/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.1ms
# video 1/1 (frame 8/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.1ms
# video 1/1 (frame 9/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.1ms
# video 1/1 (frame 10/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 45.0ms
# video 1/1 (frame 11/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 46.6ms
# video 1/1 (frame 12/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 45.1ms
# video 1/1 (frame 13/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 47.4ms
# video 1/1 (frame 14/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 47.6ms
# video 1/1 (frame 15/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 48.1ms
# video 1/1 (frame 16/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 48.1ms
# video 1/1 (frame 17/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 49.5ms
# video 1/1 (frame 18/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 49.4ms
# video 1/1 (frame 19/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 49.4ms
# video 1/1 (frame 20/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 50.2ms
# video 1/1 (frame 21/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 50.2ms
# video 1/1 (frame 22/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 42.6ms
# video 1/1 (frame 23/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 41.2ms
# video 1/1 (frame 24/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.9ms
# video 1/1 (frame 25/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.8ms
# video 1/1 (frame 26/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.2ms
# video 1/1 (frame 27/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.4ms
# video 1/1 (frame 28/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.1ms
# video 1/1 (frame 29/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.3ms
# video 1/1 (frame 30/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.4ms
# video 1/1 (frame 31/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.3ms
# video 1/1 (frame 32/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.1ms
# video 1/1 (frame 33/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 34/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 35/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.3ms
# video 1/1 (frame 36/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.2ms
# video 1/1 (frame 37/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.2ms
# video 1/1 (frame 38/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 39/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 40/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 41/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.4ms
# video 1/1 (frame 42/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.1ms
# video 1/1 (frame 43/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.8ms
# video 1/1 (frame 44/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.9ms
# video 1/1 (frame 45/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 46/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 47/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.4ms
# video 1/1 (frame 48/132) /content/drive/MyDrive/broadcast.mp4: 384x640 8 players, 39.3ms
# video 1/1 (frame 49/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.3ms
# video 1/1 (frame 50/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.1ms
# video 1/1 (frame 51/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.2ms
# video 1/1 (frame 52/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 53/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.6ms
# video 1/1 (frame 54/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 55/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 40.2ms
# video 1/1 (frame 56/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.3ms
# video 1/1 (frame 57/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 58/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 59/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 60/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.3ms
# video 1/1 (frame 61/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.3ms
# video 1/1 (frame 62/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.1ms
# video 1/1 (frame 63/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.6ms
# video 1/1 (frame 64/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.1ms
# video 1/1 (frame 65/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.3ms
# video 1/1 (frame 66/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 67/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 68/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.4ms
# video 1/1 (frame 69/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.4ms
# video 1/1 (frame 70/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.5ms
# video 1/1 (frame 71/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 40.3ms
# video 1/1 (frame 72/132) /content/drive/MyDrive/broadcast.mp4: 384x640 13 players, 39.3ms
# video 1/1 (frame 73/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.5ms
# video 1/1 (frame 74/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.6ms
# video 1/1 (frame 75/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.8ms
# video 1/1 (frame 76/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.8ms
# video 1/1 (frame 77/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.7ms
# video 1/1 (frame 78/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.8ms
# video 1/1 (frame 79/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.3ms
# video 1/1 (frame 80/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.4ms
# video 1/1 (frame 81/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 41.7ms
# video 1/1 (frame 82/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.7ms
# video 1/1 (frame 83/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.7ms
# video 1/1 (frame 84/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.9ms
# video 1/1 (frame 85/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.7ms
# video 1/1 (frame 86/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.0ms
# video 1/1 (frame 87/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 88/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 89/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 90/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.3ms
# video 1/1 (frame 91/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 92/132) /content/drive/MyDrive/broadcast.mp4: 384x640 12 players, 39.3ms
# video 1/1 (frame 93/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 94/132) /content/drive/MyDrive/broadcast.mp4: 384x640 13 players, 40.1ms
# video 1/1 (frame 95/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 96/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 97/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 98/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 99/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 100/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 39.3ms
# video 1/1 (frame 101/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 102/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.1ms
# video 1/1 (frame 103/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.4ms
# video 1/1 (frame 104/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 105/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.1ms
# video 1/1 (frame 106/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.1ms
# video 1/1 (frame 107/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 108/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 40.2ms
# video 1/1 (frame 109/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 40.1ms
# video 1/1 (frame 110/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 39.3ms
# video 1/1 (frame 111/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 39.3ms
# video 1/1 (frame 112/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 39.3ms
# video 1/1 (frame 113/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 40.2ms
# video 1/1 (frame 114/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 39.9ms
# video 1/1 (frame 115/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 43.8ms
# video 1/1 (frame 116/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 43.6ms
# video 1/1 (frame 117/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 42.2ms
# video 1/1 (frame 118/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 41.4ms
# video 1/1 (frame 119/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 41.3ms
# video 1/1 (frame 120/132) /content/drive/MyDrive/broadcast.mp4: 384x640 11 players, 41.3ms
# video 1/1 (frame 121/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 41.3ms
# video 1/1 (frame 122/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 41.3ms
# video 1/1 (frame 123/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 41.3ms
# video 1/1 (frame 124/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 41.4ms
# video 1/1 (frame 125/132) /content/drive/MyDrive/broadcast.mp4: 384x640 9 players, 41.3ms
# video 1/1 (frame 126/132) /content/drive/MyDrive/broadcast.mp4: 384x640 10 players, 41.3ms
# video 1/1 (frame 127/132) /content/drive/MyDrive/broadcast.mp4: 384x640 (no detections), 41.3ms
# video 1/1 (frame 128/132) /content/drive/MyDrive/broadcast.mp4: 384x640 2 players, 40.4ms
# video 1/1 (frame 129/132) /content/drive/MyDrive/broadcast.mp4: 384x640 1 player, 40.5ms
# video 1/1 (frame 130/132) /content/drive/MyDrive/broadcast.mp4: 384x640 (no detections), 40.4ms
# video 1/1 (frame 131/132) /content/drive/MyDrive/broadcast.mp4: 384x640 (no detections), 40.5ms
# video 1/1 (frame 132/132) /content/drive/MyDrive/broadcast.mp4: 384x640 1 player, 40.3ms
# Speed: 3.8ms preprocess, 41.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# video 1/1 (frame 1/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 51.1ms
# video 1/1 (frame 2/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 49.5ms
# video 1/1 (frame 3/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 37.6ms
# video 1/1 (frame 4/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 37.7ms
# video 1/1 (frame 5/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 37.7ms
# video 1/1 (frame 6/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 37.6ms
# video 1/1 (frame 7/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 37.7ms
# video 1/1 (frame 8/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.7ms
# video 1/1 (frame 9/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.7ms
# video 1/1 (frame 10/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.7ms
# video 1/1 (frame 11/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.7ms
# video 1/1 (frame 12/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.6ms
# video 1/1 (frame 13/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.7ms
# video 1/1 (frame 14/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 37.8ms
# video 1/1 (frame 15/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 37.6ms
# video 1/1 (frame 16/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.7ms
# video 1/1 (frame 17/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 38.0ms
# video 1/1 (frame 18/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.9ms
# video 1/1 (frame 19/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 37.7ms
# video 1/1 (frame 20/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 38.3ms
# video 1/1 (frame 21/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 22/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.4ms
# video 1/1 (frame 23/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.8ms
# video 1/1 (frame 24/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 25/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.7ms
# video 1/1 (frame 26/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.8ms
# video 1/1 (frame 27/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.9ms
# video 1/1 (frame 28/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.1ms
# video 1/1 (frame 29/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 30/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 31/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 32/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 33/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 34/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 35/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 36/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 37/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 38/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 39/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.4ms
# video 1/1 (frame 40/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 41/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 42/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.5ms
# video 1/1 (frame 43/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 44/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 45/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 46/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.8ms
# video 1/1 (frame 47/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 48/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.9ms
# video 1/1 (frame 49/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 50/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 51/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.3ms
# video 1/1 (frame 52/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 53/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 54/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 55/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 56/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 57/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.3ms
# video 1/1 (frame 58/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 59/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 60/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 61/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 62/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.5ms
# video 1/1 (frame 63/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 64/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 65/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 66/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 67/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 68/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.4ms
# video 1/1 (frame 69/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.4ms
# video 1/1 (frame 70/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 71/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.5ms
# video 1/1 (frame 72/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 41.1ms
# video 1/1 (frame 73/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.4ms
# video 1/1 (frame 74/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.3ms
# video 1/1 (frame 75/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 41.8ms
# video 1/1 (frame 76/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.7ms
# video 1/1 (frame 77/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.8ms
# video 1/1 (frame 78/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.9ms
# video 1/1 (frame 79/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 80/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.3ms
# video 1/1 (frame 81/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 82/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.1ms
# video 1/1 (frame 83/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 84/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 85/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.7ms
# video 1/1 (frame 86/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.9ms
# video 1/1 (frame 87/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.5ms
# video 1/1 (frame 88/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.9ms
# video 1/1 (frame 89/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.5ms
# video 1/1 (frame 90/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.5ms
# video 1/1 (frame 91/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.5ms
# video 1/1 (frame 92/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.1ms
# video 1/1 (frame 93/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 43.4ms
# video 1/1 (frame 94/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 45.0ms
# video 1/1 (frame 95/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 44.6ms
# video 1/1 (frame 96/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 45.0ms
# video 1/1 (frame 97/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 46.1ms
# video 1/1 (frame 98/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 46.9ms
# video 1/1 (frame 99/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 46.7ms
# video 1/1 (frame 100/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 46.4ms
# video 1/1 (frame 101/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 46.3ms
# video 1/1 (frame 102/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 46.4ms
# video 1/1 (frame 103/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 46.1ms
# video 1/1 (frame 104/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 41.4ms
# video 1/1 (frame 105/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 41.3ms
# video 1/1 (frame 106/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 41.3ms
# video 1/1 (frame 107/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 41.2ms
# video 1/1 (frame 108/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.2ms
# video 1/1 (frame 109/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 40.0ms
# video 1/1 (frame 110/201) /content/drive/MyDrive/tacticam.mp4: 384x640 18 players, 39.9ms
# video 1/1 (frame 111/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 39.9ms
# video 1/1 (frame 112/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.5ms
# video 1/1 (frame 113/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.4ms
# video 1/1 (frame 114/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 42.5ms
# video 1/1 (frame 115/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 116/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.9ms
# video 1/1 (frame 117/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 39.9ms
# video 1/1 (frame 118/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.9ms
# video 1/1 (frame 119/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 120/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 121/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 122/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 123/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.9ms
# video 1/1 (frame 124/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.8ms
# video 1/1 (frame 125/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 126/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.2ms
# video 1/1 (frame 127/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 128/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 129/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 130/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 131/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.3ms
# video 1/1 (frame 132/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.3ms
# video 1/1 (frame 133/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 134/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 135/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.3ms
# video 1/1 (frame 136/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 137/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 138/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.3ms
# video 1/1 (frame 139/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.2ms
# video 1/1 (frame 140/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 141/201) /content/drive/MyDrive/tacticam.mp4: 384x640 24 players, 40.2ms
# video 1/1 (frame 142/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.2ms
# video 1/1 (frame 143/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.3ms
# video 1/1 (frame 144/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.4ms
# video 1/1 (frame 145/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.3ms
# video 1/1 (frame 146/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 39.3ms
# video 1/1 (frame 147/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.4ms
# video 1/1 (frame 148/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 149/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.1ms
# video 1/1 (frame 150/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.3ms
# video 1/1 (frame 151/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 152/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 39.3ms
# video 1/1 (frame 153/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 39.3ms
# video 1/1 (frame 154/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.2ms
# video 1/1 (frame 155/201) /content/drive/MyDrive/tacticam.mp4: 384x640 24 players, 40.2ms
# video 1/1 (frame 156/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.2ms
# video 1/1 (frame 157/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.2ms
# video 1/1 (frame 158/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.2ms
# video 1/1 (frame 159/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 160/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 161/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 162/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.3ms
# video 1/1 (frame 163/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.2ms
# video 1/1 (frame 164/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 165/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.4ms
# video 1/1 (frame 166/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.3ms
# video 1/1 (frame 167/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.3ms
# video 1/1 (frame 168/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.1ms
# video 1/1 (frame 169/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.8ms
# video 1/1 (frame 170/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.8ms
# video 1/1 (frame 171/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 172/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 173/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.1ms
# video 1/1 (frame 174/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.1ms
# video 1/1 (frame 175/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.6ms
# video 1/1 (frame 176/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.1ms
# video 1/1 (frame 177/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.4ms
# video 1/1 (frame 178/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 179/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.2ms
# video 1/1 (frame 180/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 181/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 182/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 183/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.2ms
# video 1/1 (frame 184/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 185/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 186/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 187/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 188/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 189/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 190/201) /content/drive/MyDrive/tacticam.mp4: 384x640 20 players, 40.3ms
# video 1/1 (frame 191/201) /content/drive/MyDrive/tacticam.mp4: 384x640 23 players, 40.3ms
# video 1/1 (frame 192/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 40.2ms
# video 1/1 (frame 193/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.3ms
# video 1/1 (frame 194/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 195/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 196/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.4ms
# video 1/1 (frame 197/201) /content/drive/MyDrive/tacticam.mp4: 384x640 19 players, 40.2ms
# video 1/1 (frame 198/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 40.2ms
# video 1/1 (frame 199/201) /content/drive/MyDrive/tacticam.mp4: 384x640 21 players, 39.3ms
# video 1/1 (frame 200/201) /content/drive/MyDrive/tacticam.mp4: 384x640 22 players, 39.6ms
# video 1/1 (frame 201/201) /content/drive/MyDrive/tacticam.mp4: 384x640 17 players, 40.2ms
# Speed: 3.4ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Done. Videos saved.

# %% [markdown]
# Evalute

# %%
db_x = cam_x.get_database()
db_y = cam_y.get_database()

print("\n======================================")
print(" CROSS-CAMERA SYSTEM EVALUATION")
print("======================================\n")

# 1️⃣ Cosine similarity
similarities = []
for y_id, x_id in matches.items():
    if x_id in db_x and y_id in db_y:
        emb_x = db_x[x_id]["embedding"]
        emb_y = db_y[y_id]["embedding"]
        emb_x = emb_x / np.linalg.norm(emb_x)
        emb_y = emb_y / np.linalg.norm(emb_y)
        sim = np.dot(emb_x, emb_y)
        similarities.append(sim)

if similarities:
    print("Average Cosine Similarity:", round(np.mean(similarities),4))
    print("Min Similarity:", round(np.min(similarities),4))
    print("Max Similarity:", round(np.max(similarities),4))
    print("Std Dev:", round(np.std(similarities),4))
else:
    print("No matches found.")

# Matching coverage
total_tracks_y = len(db_y)
matched_tracks = len(matches)
unmatched_tracks = total_tracks_y - matched_tracks
print("\nMatching Coverage:")
print("Total Tracks in Camera Y:", total_tracks_y)
print("Matched Tracks:", matched_tracks)
print("Unmatched Tracks:", unmatched_tracks)
print("Coverage %:", round((matched_tracks / total_tracks_y)*100,2))

#Average track length
def compute_avg_length(db):
    lengths = [len(db[t]["frames"]) for t in db]
    return np.mean(lengths), np.min(lengths), np.max(lengths)

avg_x, min_x, max_x = compute_avg_length(db_x)
avg_y, min_y, max_y = compute_avg_length(db_y)

print("\nTrack Length Statistics:")
print("Camera X → Avg:", round(avg_x,2), "Min:", min_x, "Max:", max_x)
print("Camera Y → Avg:", round(avg_y,2), "Min:", min_y, "Max:", max_y)

#Track stability (motion jitter)
def compute_stability(db):
    displacements = []
    for t in db:
        centers = db[t]["centers"]
        if len(centers)>1:
            for i in range(1, len(centers)):
                d = np.linalg.norm(np.array(centers[i]) - np.array(centers[i-1]))
                displacements.append(d)
    return np.mean(displacements), np.std(displacements)

mean_x, std_x = compute_stability(db_x)
mean_y, std_y = compute_stability(db_y)

print("\nTrack Stability (Lower = Smoother):")
print("Camera X → Avg Motion:", round(mean_x,2), "Std:", round(std_x,2))
print("Camera Y → Avg Motion:", round(mean_y,2), "Std:", round(std_y,2))

print("\nEvaluation Complete.")
# Out:
# ======================================
#  CROSS-CAMERA SYSTEM EVALUATION
# ======================================
#
# Average Cosine Similarity: 0.9132
# Min Similarity: 0.7465
# Max Similarity: 0.9916
# Std Dev: 0.0708
#
# Matching Coverage:
# Total Tracks in Camera Y: 30
# Matched Tracks: 27
# Unmatched Tracks: 3
# Coverage %: 90.0
#
# Track Length Statistics:
# Camera X → Avg: 51.8 Min: 1 Max: 120
# Camera Y → Avg: 142.17 Min: 1 Max: 201
#
# Track Stability (Lower = Smoother):
# Camera X → Avg Motion: 6.18 Std: 7.62
# Camera Y → Avg Motion: 2.42 Std: 2.06
#
# Evaluation Complete.
